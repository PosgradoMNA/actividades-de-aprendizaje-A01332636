# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01332636/blob/main/M%C3%B3dulo4_DataAnalysis_w_Python(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Módulo 4, Data Analysis with Python (IBM)
# ##Datos generales
# Nombre: Estefania Abigail Castro Belmont
#
# Matrícula: A01332636
#
# Materia: Ciencia y analítica de datos
#
# Profesor: María de la Paz Rico Fernández
#
# Tutor: Julio César Galindo López
#
# Fecha: 27/10/2022

# %% [markdown]
# ##Model Development

# %% [markdown]
# Learning Objectives
# 1. Simple and multiple linear regression
# 2. Model evaluation using visualization
# 3. Polynomial regression and pipelines
# 4. R-squared and MSE for In-Sample evaluation
# 5. Prediction and decision making
#
# * A model can be thought of as a mathematical equation used to predict a value given one or more values
#
# * Relating one or more independent variables to dependen variables

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Usually the more relevant data you have the more accurate your model is:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Linear and Multiple Linear Regression

# %% [markdown]
# ###Simple Linear Regression

# %% [markdown]
# 1. The predictor (independent) variable - x
# 2. The target (dependent) variable - y

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Fitting a Simple Linear Model Estimator

# %% [markdown]
# X : Predictor Variable
# Y : Target Variable
#
# 1. Import linea_model from scikit-learn
#
#     `from sklearn.linear_model import LinearRegression`
# 2. Create a Linear Regression Object using the constructor
#
#     `lm = LinearRegression()`
# 3. We define the predicvtor variable and target variable
#
#     `X = df[['highway-mpg']]`
#
#     `Y = df['price']`
# 4. Then use lm.fit (X,Y) fot fit the model, i.e fine the parameters b0 and b1
#
#     `lm.fit(X,Y)`
# 5. We can obtain a prediction
#
#     `Yhat = lm.predict(X)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Multiple Linear Regression (MLR)

# %% [markdown]
# This method is used to explain the relationships between
# * One continuos target (Y) variable
# * Two or more predictor (X) variables

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Fitting a Multiple Linear Model Estimator

# %% [markdown]
# 1.  We can extract the 4 predictor variables and store them in the variable Z.
#
#     `Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]`
# 2.  Then train the model as before using the method train, with the features or dependent
#
#     `lm.fit(Z,df['price'])`
#
# 3. We can also obtain a prediction
#
#     `Yhat = lm.predict(X)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Model Evaluation using Visualization

# %% [markdown]
# ###Regression Plot

# %% [markdown]
# It gives us a goos estimate of:
#
# 1. The relationship between two variables
# 2. The strength of the correlation
# 3. The direction of the relationship (positive or negative).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How to plot a regression plot
#
# `import seaborn as sns`
#
# `sns.regplot(x='highway-mpg', y='price', data = df)`
#
# `plt.ylim(0,)`

# %% [markdown]
# ###Residual Plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How to plot
#
# `import seaborn as sns`
#
# `sns.resiplot(df['highway-mpg'], df['price'])`

# %% [markdown]
# ###Distribution Plots

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Code
#
# `import seaborn as sns`
#
# `ax1 = snsdisplot(df['price'], hist = False, color = 'r', label = "Actual Value")`
#
# `sns.display(Yhat, hist = False, color = 'b', label = "Fitted Values", ax = ax1)`

# %% [markdown]
# ##Polynomial Regression and Pipelines

# %% [markdown]
# ###Polynomial Regression

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Calculate Polynomial of 3rd order
#
# `f =np.polyfit(x,y,3)`
#
# `p = np.polyld(f)`
#
# `prunt(p)`

# %% [markdown]
# We can also have multi-dimensional polynomial linear regression.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We use the "preprocessing" library in sci-kit-learn, to create a polynomial feature object.
#
# `from sklearn.preprocessing import PolynomialFeatures`
#
# `pr = PolynomialFeatures(degree = 2, include_bias = False)`
#
# `x_polly = pr.fit_transform(x[['horsepower','curb-weight']]`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Pipelines

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
#
# `SCALE = StandardScaler()`
#
# `SCALE.fit(X_data[['horsepower','highway-mpg']])`
#
# `x_scale = SCALE.transform(X_data[['horsepower','highway-mpg']])`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Measures for In-Sample Evaluation

# %% [markdown]
# ###Mean Squared Error (MSE)

# %% [markdown]
# A way to numerically determine how good the model fits on our data.
#
# Two important measures that we often use to determine the fit of a model are:
# * Mean Square
#
# * Error (MSE), and R-squared.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In python we can measure the MSE as follows
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###R-squared

# %% [markdown]
# R-squared is also called the coefficient of determination.
#
# * It’s a measure to determine how close the data is to the fitted regression line.
# * R^2: the percentage of variation of the target variable (Y) that is explained by the linear model
# * Think about as comparing a regression model to a simple model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Prediction and Decision Making

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##LAB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# ###Linear Regression and Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['highway-mpg']]
Y = df['price']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# ###Q1 a

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# ###Q1 b

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1
# Out:
# LinearRegression()

# %% [markdown]
# ###Q1 c

# %%
lm1.coef_
# Out:
# array([[166.86001569]])

# %%
lm1.intercept_
# Out:
# array([-7963.33890628])

# %% [markdown]
# ###Q1 d

# %%
Yhat=-7963.34 + 166.86*X

Price=-7963.34 + 166.86*df['engine-size']

# %%
#Let's develop a model using these variables as the predictor variables.
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
#Fit the linear model using the four above-mentioned variables.

lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
#What is the value of the intercept(a)?

lm.intercept_
# Out:
# -15806.62462632922

# %%
#What are the values of the coefficients (b1, b2, b3, b4)?

lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# ###Q2 a

# %%
lm2 = LinearRegression()
lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# ###Q2 b

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %% [markdown]
# ###Model evaluation using visualization

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline

# %%
#Let's visualize highway-mpg as potential predictor variable of price:

width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48170.903553758006)

# %%
#Let's compare this plot to the regression plot of "peak-rpm".

plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# ###Q3

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'],y=df['price'])
plt.show()

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###Polynomial Regression and Pipelines

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

# %%
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# ###Q4

# %%
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %%
Z_pr.shape
# Out:
# (201, 15)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %% [markdown]
# ###Q5

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %% [markdown]
# ###Measures fo In-Sample Evaluation

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4965911884339176

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639888

# %%
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577457

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.87072649

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression()

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# ##Course Progrss

# %% [markdown]
# ![image.png](data:image/png;base64,...)
